# %%
import json
import os
import time

from datetime import datetime

from os.path import dirname, realpath
import sys
sys.path.append(dirname(dirname(realpath(os.getcwd()))))
import pickle
import torch
import multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
from collections import Counter
from copy import deepcopy
import datetime
import tqdm
import numpy as np
import random
from collections import Counter
sys.path.append("./src/")


import datetime
def parse_date(date_str):
    if date_str == 'NA' or date_str is None:
        return datetime.datetime(9999,1,1,0,0)
    else:
        if len(date_str) == 10:
            format_str = '%Y-%m-%d'
        else:
            raise Exception("Format for {} not recognized!".format(date_str))
    return datetime.datetime.strptime(date_str, format_str)

# %%
VTE_path = 'Y:\\Fillmore_Cancer\\cat\\Users\\data\\derived\\vte_ml\\vte_ml\\data_for_chunlei'
train_path = os.path.join(VTE_path, 'A2_CMP\\train\\train.json')
#test_path = os.path.join(VTE_path, 'A2_CMP\\XPheLab_CMP.json')

# %%
X = json.load(open(os.path.join(train_path), 'r'))

# %%
import pandas as pd

# %%
import statistics

# %%
import numpy as np

# %%
import pdb
import argparse

END_OF_TIME_DATE = datetime.datetime(2020, 12, 31, 0, 0)
OUTCOME_CODE = ['VTE']
BASELINE = []

UNK_TOKEN = '<UNK>'
PAD_TOKEN = '<PAD>'
MAX_TIME_EMBED_PERIOD_IN_DAYS = 12 * 365
MIN_TIME_EMBED_PERIOD_IN_DAYS = 10

SUMMARY_MSG = "Contructed BTH Disease Progression DiseaseRisk {} dataset with {} records, {} patients, and the following class balance \n {}"
NO_DATASET_ERR = "Dataset {} not in DATASET_REGISTRY! Available datasets are {}"
DATASET_REGISTRY = {}
NUM_PICKLES = 50
UNK_TOKEN = '<UNK>'
PAD_TOKEN = '<PAD>'
NO_OP_TOKEN = '_'

parser = argparse.ArgumentParser(description='DiskRisk Classifier')

# %%
#args = parse_args()
#args = parser.parse_args()

# %%
# these are VTE patients
patient_id = '1004562085'
#patient_id = '1003839942'
#patient_id = '1003839942'

# %%
def process_events1(events, end_date=None):
    for event in events:
        if 'admdate' in event.keys():
            event['admit_date'] = parse_date(event['admdate'])
        else:
            events.remove(event)
    if end_date is not None:
        start_date, start_admid = min([(e['admit_date'], e['admid']) for e in events])
        year_range = (end_date - start_date).days // 365
        for year in range(year_range):
            events.append(get_no_op_event1(start_date, year, start_admid))
    events = sorted(events, key=lambda event: event['admit_date'])
    return events


def process_events2(events, end_date=None):
    for event in events:
        if event['admdate'] is not None:
            # test = event['admdate']
            event['admit_date'] = parse_date(event['admdate'])
        else:
            events.remove(event)
    if end_date is not None:
        start_date, start_admid = min([(e['admit_date'], e['admid']) for e in events])
        year_range = (end_date - start_date).days // 365
        for year in range(year_range):
            events.append(get_no_op_event1(start_date, year, start_admid))
    events = sorted(events, key=lambda event: event['admit_date'])
    return events

def get_no_op_event1( start_date, year, admid_base):
    code = NO_OP_TOKEN
    new_date = start_date + datetime.timedelta(365 * year)
    event = {'admit_date': new_date, 'codes': code, 'hospital': 'n/a', 'admid': '{}_{}'.format(admid_base, year)}
    return event
def get_outcome_date1(events, index_date, end_of_date=END_OF_TIME_DATE):
    '''
    Looks through events to find date of outcome
    If multiple outcomes occur, use the first occurance date.
    args:
    - events: List of event dicts. Each dict must have a CODE and admit_date.
    '''
    outcome_events = [e for e in events if any(icd == e['codes'] for icd in OUTCOME_CODE)]

    if len(outcome_events) > 0:
        ever_develops_outcome = True
        time = min([e['admit_date'] for e in outcome_events])
    else:
        ever_develops_outcome = False
        time = end_of_date
    return ever_develops_outcome, time

# %%
patient_metadata = X

# %%
# Out:
# 0

# %%
1010699701

# %%
1009420808
# Out:
# 1009420808

# %%
patient_id = '1003790557'

# %%
#patient_id = '1001720232'  # for a control

# %%
obs_time_end = parse_date(patient_metadata[patient_id]['end_of_data'])
dob = parse_date(patient_metadata[patient_id]['birthdate'])            
index_date = parse_date(patient_metadata[patient_id]['indexdate'])
dx_date = parse_date(patient_metadata[patient_id]['dxdate'])
ks = patient_metadata[patient_id]['ks_mod_score']
sex = patient_metadata[patient_id]['gender']
bmi = patient_metadata[patient_id]['BMI']
race = patient_metadata[patient_id]['Race']

# %%
patient_dict = {'patient_id': patient_id}

# %%
 def get_outcome_date1(events, index_date, end_of_date=END_OF_TIME_DATE):
        '''
        Looks through events to find date of outcome
        If multiple outcomes occur, use the first occurance date.
        args:
        - events: List of event dicts. Each dict must have a CODE and admit_date.
        '''
        outcome_events = [e for e in events if any(icd == e['codes'] for icd in OUTCOME_CODE)]

        if len(outcome_events) > 0:
            ever_develops_outcome = True
            time = min([e['admit_date'] for e in outcome_events])
        else:
            ever_develops_outcome = False
            time = end_of_date
        return ever_develops_outcome, time

# %%
obs_time_end
# Out:
# datetime.datetime(2015, 1, 22, 0, 0)

# %%
feat_subgroup = {'birth_date': patient_metadata[patient_id]['birthdate']}
split_group = 'test'

# %%
events = process_events1(patient_metadata[patient_id]['events'], obs_time_end)
outcome, outcome_date = get_outcome_date1 ( events, index_date, 
                                                                     end_of_date=obs_time_end)

# %%
outcome
# Out:
# True

# %%
outcome_date
# Out:
# datetime.datetime(2013, 2, 4, 0, 0)

# %%
ev_dates = [events[i]['admit_date'] for i in range(len(events))]

# %%
            t1 = index_date + datetime.timedelta( 30 ) 
            t2 = index_date + datetime.timedelta( 90 )  
            t3 = index_date + datetime.timedelta( 180 )  
            t4 = index_date + datetime.timedelta( 270 )

# %%
t1
# Out:
# datetime.datetime(2012, 11, 4, 0, 0)

# %%
t2
# Out:
# datetime.datetime(2013, 1, 3, 0, 0)

# %%
  def find_closest_date_before(reference_date, dates):
        index = bisect_left(dates, reference_date)
        if index == 0:
            return None  # No date before the reference date
        return index - 1

# %%
from bisect import bisect_left

# %%
  
            selected_idx =  [find_closest_date_before(t1, ev_dates), 
                             find_closest_date_before(t2, ev_dates),
                             find_closest_date_before(t3, ev_dates),
                             find_closest_date_before(t4, ev_dates),]

# %%
selected_idx
# Out:
# [225, 225, 251, 275]

# %%
[t1,t2,t3,t4]
# Out:
# [datetime.datetime(2012, 11, 4, 0, 0),
#  datetime.datetime(2013, 1, 3, 0, 0),
#  datetime.datetime(2013, 4, 3, 0, 0),
#  datetime.datetime(2013, 7, 2, 0, 0)]

# %%
[t1,t2,t3,t4]>outcome_date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 [t1,t2,t3,t4]>outcome_date
#
# TypeError: '>' not supported between instances of 'list' and 'datetime.datetime'

# %%
list( compress(selected_idx, valid))
# Out:
# [225, 225]

# %%
sel_i =  [find_closest_date_before(t1, ev_dates), 
          find_closest_date_before(t2, ev_dates),
          find_closest_date_before(t3, ev_dates),
          find_closest_date_before(t4, ev_dates),]    
valid =  [i<outcome_date for i in [t1,t2,t3,t4]]
selected_idx = list( compress(sel_i, valid))

# %%
selected_idx
# Out:
# [225, 225]

# %%
valid =  [i<outcome_date for i in [t1,t2,t3,t4]]

# %%
selected_idx[valid]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 selected_idx[valid]
#
# TypeError: list indices must be integers or slices, not list

# %%
np.argmin( [abs(ev_dates[i] - index_date) for i in range(len(ev_dates ))])
# Out:
# 2432

# %%
outcome_date
# Out:
# datetime.datetime(2015, 2, 27, 0, 0)

# %%
lookback = outcome_date + datetime.timedelta(42)
selected_idx =  [np.argmin( [abs(ev_dates[i] - lookback) for i in range(len(ev_dates ))])]

# %%
selected_idx
# Out:
# [2990]

# %%
  for idx in selected_idx:
            events_to_date = events[:idx + 1]

# %%
outcome
# Out:
# False

# %%
ev_dates[selected_idx[0]] > lookback
# Out:
# True

# %%
ev_dates[selected_idx[0]]
# Out:
# datetime.datetime(2015, 4, 13, 0, 0)

# %%
lookback
# Out:
# datetime.datetime(2015, 4, 10, 0, 0)

# %%
selected_idx1 =  [np.argmin([ np.max( np.array(lookback-ev_dates[i]), 0 ) for i in range(len(ev_dates ))])]

# %%
selected_idx1
# Out:
# [3003]

# %%
ev_dates[selected_idx[0]]
# Out:
# datetime.datetime(2015, 4, 13, 0, 0)

# %%
ev_dates[selected_idx1[0]]
# Out:
# datetime.datetime(2015, 7, 21, 0, 0)

# %%
lookback
# Out:
# datetime.datetime(2015, 4, 10, 0, 0)

# %%
selected_idx2 =  [np.argmin([ np.max( np.array(ev_dates[i]-lookback), 0 ) for i in range(len(ev_dates ))])]

# %%
np.argmax([ np.max( np.array(lookback - ev_dates[i]), 0 ) for i in range(len(ev_dates ))])
# Out:
# 0

# %%
from bisect import bisect_left

# %%
def find_closest_date_before(reference_date, dates):
    index = bisect_left(dates, reference_date)
    if index == 0:
        return None  # No date before the reference date
    return index - 1

# %%
find_closest_date_before(lookback, ev_dates)
# Out:
# 2989

# %%
ev_dates[2989]
# Out:
# datetime.datetime(2015, 3, 24, 0, 0)

# %%
lookback > outcome_date
# Out:
# True

# %%
outcome_date
# Out:
# datetime.datetime(2015, 2, 27, 0, 0)

# %%
lookback
# Out:
# datetime.datetime(2015, 4, 10, 0, 0)

# %%
selected_idx = find_closest_date_before(lookback, ev_dates)

# %%
for idx in [selected_idx]:
    events_to_date = events[:idx + 1]

# %%
events_to_date
# Out:
# [{'admdate': '1999-10-01',
#   'admid': '0010446036',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 1, 0, 0)},
#  {'admit_date': datetime.datetime(1999, 10, 1, 0, 0),
#   'codes': '_',
#   'hospital': 'n/a',
#   'admid': '0010446036_0'},
#  {'admdate': '1999-10-04',
#   'admid': '0010447516',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 4, 0, 0)},
#  {'admdate': '1999-10-06',
#   'admid': '0010448097',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 6, 0, 0)},
#  {'admdate': '1999-10-08',
#   'admid': '0010448068',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 8, 0, 0)},
#  {'admdate': '1999-10-12',
#   'admid': '0010447972',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 12, 0, 0)},
#  {'admdate': '1999-10-14',
#   'admid': '0010447636',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(1999, 10, 14, 0, 0)},
#  {'admdate': '1999-10-14',
#   'admid': '0010447637',
#   'codes': '401',
#   'admit_date': datetime.datetime(1999, 10, 14, 0, 0)},
#  {'admdate': '1999-10-14',
#   'admid': '0010448018',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 14, 0, 0)},
#  {'admdate': '1999-10-14',
#   'admid': '0010448019',
#   'codes': '296.2',
#   'admit_date': datetime.datetime(1999, 10, 14, 0, 0)},
#  {'admdate': '1999-10-14',
#   'admid': '0010448020',
#   'codes': '296',
#   'admit_date': datetime.datetime(1999, 10, 14, 0, 0)},
#  {'admdate': '1999-10-15',
#   'admid': '0010447912',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 15, 0, 0)},
#  {'admdate': '1999-10-18',
#   'admid': '0010447537',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 18, 0, 0)},
#  {'admdate': '1999-10-19',
#   'admid': '0010448054',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 19, 0, 0)},
#  {'admdate': '1999-10-19',
#   'admid': '0010449432',
#   'codes': '318',
#   'admit_date': datetime.datetime(1999, 10, 19, 0, 0)},
#  {'admdate': '1999-10-20',
#   'admid': '0010446032',
#   'codes': '318',
#   'admit_date': datetime.datetime(1999, 10, 20, 0, 0)},
#  {'admdate': '1999-10-20',
#   'admid': '0010448073',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 20, 0, 0)},
#  {'admdate': '1999-10-22',
#   'admid': '0010446020',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 22, 0, 0)},
#  {'admdate': '1999-10-25',
#   'admid': '0010447605',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 25, 0, 0)},
#  {'admdate': '1999-10-25',
#   'admid': '0010447606',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(1999, 10, 25, 0, 0)},
#  {'admdate': '1999-10-27',
#   'admid': '0010446039',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(1999, 10, 27, 0, 0)},
#  {'admdate': '1999-10-27',
#   'admid': '0010446040',
#   'codes': '272',
#   'admit_date': datetime.datetime(1999, 10, 27, 0, 0)},
#  {'admdate': '1999-10-27',
#   'admid': '0010446041',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 27, 0, 0)},
#  {'admdate': '1999-10-28',
#   'admid': '0010447874',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 28, 0, 0)},
#  {'admdate': '1999-10-28',
#   'admid': '0010448584',
#   'codes': '296.2',
#   'admit_date': datetime.datetime(1999, 10, 28, 0, 0)},
#  {'admdate': '1999-10-28',
#   'admid': '0010448585',
#   'codes': '296',
#   'admit_date': datetime.datetime(1999, 10, 28, 0, 0)},
#  {'admdate': '1999-10-29',
#   'admid': '0010449469',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 10, 29, 0, 0)},
#  {'admdate': '1999-11-01',
#   'admid': '0010445060',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 1, 0, 0)},
#  {'admdate': '1999-11-03',
#   'admid': '0010447929',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 3, 0, 0)},
#  {'admdate': '1999-11-03',
#   'admid': '0010448107',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(1999, 11, 3, 0, 0)},
#  {'admdate': '1999-11-03',
#   'admid': '0010448108',
#   'codes': '272',
#   'admit_date': datetime.datetime(1999, 11, 3, 0, 0)},
#  {'admdate': '1999-11-03',
#   'admid': '0010448109',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(1999, 11, 3, 0, 0)},
#  {'admdate': '1999-11-03',
#   'admid': '0010448110',
#   'codes': '401',
#   'admit_date': datetime.datetime(1999, 11, 3, 0, 0)},
#  {'admdate': '1999-11-04',
#   'admid': '0010447942',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 4, 0, 0)},
#  {'admdate': '1999-11-05',
#   'admid': '0010447514',
#   'codes': '316',
#   'admit_date': datetime.datetime(1999, 11, 5, 0, 0)},
#  {'admdate': '1999-11-08',
#   'admid': '0010448115',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 8, 0, 0)},
#  {'admdate': '1999-11-09',
#   'admid': '0010445055',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 9, 0, 0)},
#  {'admdate': '1999-11-10',
#   'admid': '0010446062',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 10, 0, 0)},
#  {'admdate': '1999-11-12',
#   'admid': '0010449486',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 12, 0, 0)},
#  {'admdate': '1999-11-15',
#   'admid': '0010448539',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 15, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010447626',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010448571',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010448572',
#   'codes': '401',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010448573',
#   'codes': '760',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010448574',
#   'codes': '562.2',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-17',
#   'admid': '0010448575',
#   'codes': '562',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Albumin2',
#   'admid': '2000435042',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'AlkalinePhosphatase3',
#   'admid': '2005786847',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'ALT1',
#   'admid': '2010716523',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'AST1',
#   'admid': '2015956924',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Bilirubin2',
#   'admid': '2020935314',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025990093',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041038939',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048558169',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056552101',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064440545',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072666946',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Protein2',
#   'admid': '2080717707',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085658168',
#   'admdate': '1999-11-17',
#   'admit_date': datetime.datetime(1999, 11, 17, 0, 0)},
#  {'admdate': '1999-11-18',
#   'admid': '0010447547',
#   'codes': '296.2',
#   'admit_date': datetime.datetime(1999, 11, 18, 0, 0)},
#  {'admdate': '1999-11-18',
#   'admid': '0010447548',
#   'codes': '296',
#   'admit_date': datetime.datetime(1999, 11, 18, 0, 0)},
#  {'admdate': '1999-11-18',
#   'admid': '0010447866',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 18, 0, 0)},
#  {'admdate': '1999-11-19',
#   'admid': '0010447883',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 19, 0, 0)},
#  {'admdate': '1999-11-22',
#   'admid': '0010448570',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 22, 0, 0)},
#  {'admdate': '1999-11-23',
#   'admid': '0010445056',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 23, 0, 0)},
#  {'admdate': '1999-11-24',
#   'admid': '0010448592',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 24, 0, 0)},
#  {'admdate': '1999-11-29',
#   'admid': '0010445058',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 11, 29, 0, 0)},
#  {'admdate': '1999-12-01',
#   'admid': '0010449503',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 1, 0, 0)},
#  {'admdate': '1999-12-01',
#   'admid': '0010449504',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(1999, 12, 1, 0, 0)},
#  {'admdate': '1999-12-02',
#   'admid': '0010447608',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 2, 0, 0)},
#  {'admdate': '1999-12-02',
#   'admid': '0010449499',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(1999, 12, 2, 0, 0)},
#  {'admdate': '1999-12-03',
#   'admid': '0010445989',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 3, 0, 0)},
#  {'admdate': '1999-12-03',
#   'admid': '0010447646',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(1999, 12, 3, 0, 0)},
#  {'admdate': '1999-12-03',
#   'admid': '0010447647',
#   'codes': '401',
#   'admit_date': datetime.datetime(1999, 12, 3, 0, 0)},
#  {'admdate': '1999-12-06',
#   'admid': '0010447591',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(1999, 12, 6, 0, 0)},
#  {'admdate': '1999-12-06',
#   'admid': '0010447592',
#   'codes': '401',
#   'admit_date': datetime.datetime(1999, 12, 6, 0, 0)},
#  {'admdate': '1999-12-06',
#   'admid': '0010447593',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 6, 0, 0)},
#  {'admdate': '1999-12-07',
#   'admid': '0010448533',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 7, 0, 0)},
#  {'admdate': '1999-12-08',
#   'admid': '0010448523',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 8, 0, 0)},
#  {'admdate': '1999-12-09',
#   'admid': '0010448545',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 9, 0, 0)},
#  {'admdate': '1999-12-10',
#   'admid': '0010448084',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 10, 0, 0)},
#  {'admdate': '1999-12-13',
#   'admid': '0010448011',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 13, 0, 0)},
#  {'admdate': '1999-12-14',
#   'admid': '0010446050',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 14, 0, 0)},
#  {'admdate': '1999-12-15',
#   'admid': '0010447878',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 15, 0, 0)},
#  {'admdate': '1999-12-15',
#   'admid': '0010447879',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(1999, 12, 15, 0, 0)},
#  {'admdate': '1999-12-16',
#   'admid': '0010447614',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 16, 0, 0)},
#  {'admdate': '1999-12-16',
#   'admid': '0010449425',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(1999, 12, 16, 0, 0)},
#  {'admdate': '1999-12-17',
#   'admid': '0010447635',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 17, 0, 0)},
#  {'admdate': '1999-12-20',
#   'admid': '0010447981',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 20, 0, 0)},
#  {'admdate': '1999-12-22',
#   'admid': '0010446043',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 22, 0, 0)},
#  {'admdate': '1999-12-27',
#   'admid': '0010448017',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 27, 0, 0)},
#  {'admdate': '1999-12-28',
#   'admid': '0010445057',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 28, 0, 0)},
#  {'admdate': '1999-12-29',
#   'admid': '0010447583',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 29, 0, 0)},
#  {'admdate': '1999-12-30',
#   'admid': '0010448088',
#   'codes': '317',
#   'admit_date': datetime.datetime(1999, 12, 30, 0, 0)},
#  {'admdate': '2000-01-03',
#   'admid': '0010445987',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 3, 0, 0)},
#  {'admdate': '2000-01-05',
#   'admid': '0010448546',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 5, 0, 0)},
#  {'admdate': '2000-01-07',
#   'admid': '0010448031',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 7, 0, 0)},
#  {'admdate': '2000-01-10',
#   'admid': '0010449439',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 10, 0, 0)},
#  {'admdate': '2000-01-11',
#   'admid': '0010448104',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 11, 0, 0)},
#  {'admdate': '2000-01-12',
#   'admid': '0010447545',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 12, 0, 0)},
#  {'admdate': '2000-01-13',
#   'admid': '0010445061',
#   'codes': '296.2',
#   'admit_date': datetime.datetime(2000, 1, 13, 0, 0)},
#  {'admdate': '2000-01-13',
#   'admid': '0010445062',
#   'codes': '296',
#   'admit_date': datetime.datetime(2000, 1, 13, 0, 0)},
#  {'admdate': '2000-01-13',
#   'admid': '0010445063',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 13, 0, 0)},
#  {'admdate': '2000-01-19',
#   'admid': '0010448116',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 19, 0, 0)},
#  {'admdate': '2000-01-24',
#   'admid': '0010447629',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 24, 0, 0)},
#  {'admdate': '2000-01-26',
#   'admid': '0010447867',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 26, 0, 0)},
#  {'admdate': '2000-01-27',
#   'admid': '0010447551',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 27, 0, 0)},
#  {'admdate': '2000-01-27',
#   'admid': '0010449472',
#   'codes': '296.2',
#   'admit_date': datetime.datetime(2000, 1, 27, 0, 0)},
#  {'admdate': '2000-01-27',
#   'admid': '0010449473',
#   'codes': '296',
#   'admit_date': datetime.datetime(2000, 1, 27, 0, 0)},
#  {'admdate': '2000-01-28',
#   'admid': '0010448564',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 28, 0, 0)},
#  {'admdate': '2000-01-31',
#   'admid': '0010445067',
#   'codes': '318',
#   'admit_date': datetime.datetime(2000, 1, 31, 0, 0)},
#  {'admdate': '2000-01-31',
#   'admid': '0010447538',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 1, 31, 0, 0)},
#  {'admdate': '2000-02-02',
#   'admid': '0010448082',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 2, 0, 0)},
#  {'admdate': '2000-02-07',
#   'admid': '0010447535',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 7, 0, 0)},
#  {'admdate': '2000-02-08',
#   'admid': '0010448119',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 8, 0, 0)},
#  {'admdate': '2000-02-09',
#   'admid': '0010447534',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 9, 0, 0)},
#  {'admdate': '2000-02-10',
#   'admid': '0010447573',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 10, 0, 0)},
#  {'admdate': '2000-02-10',
#   'admid': '0010447574',
#   'codes': '313.1',
#   'admit_date': datetime.datetime(2000, 2, 10, 0, 0)},
#  {'admdate': '2000-02-10',
#   'admid': '0010447575',
#   'codes': '313',
#   'admit_date': datetime.datetime(2000, 2, 10, 0, 0)},
#  {'admdate': '2000-02-15',
#   'admid': '0010445064',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 15, 0, 0)},
#  {'admdate': '2000-02-16',
#   'admid': '0010447868',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 16, 0, 0)},
#  {'admdate': '2000-02-17',
#   'admid': '0010447508',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 17, 0, 0)},
#  {'admdate': '2000-02-18',
#   'admid': '0010449508',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 18, 0, 0)},
#  {'admdate': '2000-02-22',
#   'admid': '0010445068',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 22, 0, 0)},
#  {'admdate': '2000-02-23',
#   'admid': '0010447587',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 23, 0, 0)},
#  {'admdate': '2000-02-24',
#   'admid': '0010445059',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 24, 0, 0)},
#  {'admdate': '2000-02-25',
#   'admid': '0010449464',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 25, 0, 0)},
#  {'admdate': '2000-02-28',
#   'admid': '0010446073',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 2, 28, 0, 0)},
#  {'admdate': '2000-03-01',
#   'admid': '0010449489',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 1, 0, 0)},
#  {'admdate': '2000-03-02',
#   'admid': '0010447639',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 2, 0, 0)},
#  {'admdate': '2000-03-03',
#   'admid': '0010445980',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 3, 0, 0)},
#  {'admdate': '2000-03-06',
#   'admid': '0010448047',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 6, 0, 0)},
#  {'admdate': '2000-03-07',
#   'admid': '0010447900',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 7, 0, 0)},
#  {'admdate': '2000-03-08',
#   'admid': '0010446049',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 8, 0, 0)},
#  {'admdate': '2000-03-09',
#   'admid': '0010447922',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 9, 0, 0)},
#  {'admdate': '2000-03-10',
#   'admid': '0010447586',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 10, 0, 0)},
#  {'admdate': '2000-03-13',
#   'admid': '0010448029',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 13, 0, 0)},
#  {'admdate': '2000-03-14',
#   'admid': '0010447928',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 14, 0, 0)},
#  {'admdate': '2000-03-16',
#   'admid': '0010447550',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 16, 0, 0)},
#  {'admdate': '2000-03-17',
#   'admid': '0010448083',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 17, 0, 0)},
#  {'admdate': '2000-03-17',
#   'admid': '0010448098',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(2000, 3, 17, 0, 0)},
#  {'admdate': '2000-03-17',
#   'admid': '0010448099',
#   'codes': '401',
#   'admit_date': datetime.datetime(2000, 3, 17, 0, 0)},
#  {'admdate': '2000-03-20',
#   'admid': '0010446012',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025993267',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041210122',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048558164',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056551979',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064440544',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072666947',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085660250',
#   'admdate': '2000-03-20',
#   'admit_date': datetime.datetime(2000, 3, 20, 0, 0)},
#  {'admdate': '2000-03-21',
#   'admid': '0010446065',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 21, 0, 0)},
#  {'admdate': '2000-03-22',
#   'admid': '0010447871',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 22, 0, 0)},
#  {'admdate': '2000-03-23',
#   'admid': '0010447581',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 23, 0, 0)},
#  {'admdate': '2000-03-24',
#   'admid': '0010447512',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 24, 0, 0)},
#  {'admdate': '2000-03-27',
#   'admid': '0010448581',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 27, 0, 0)},
#  {'admdate': '2000-03-28',
#   'admid': '0010445069',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 28, 0, 0)},
#  {'admdate': '2000-03-29',
#   'admid': '0010446002',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 29, 0, 0)},
#  {'admdate': '2000-03-30',
#   'admid': '0010448547',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 30, 0, 0)},
#  {'admdate': '2000-03-31',
#   'admid': '0010447641',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 3, 31, 0, 0)},
#  {'admdate': '2000-04-03',
#   'admid': '0010447519',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 3, 0, 0)},
#  {'admdate': '2000-04-04',
#   'admid': '0010446038',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 4, 0, 0)},
#  {'admdate': '2000-04-05',
#   'admid': '0010448075',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 5, 0, 0)},
#  {'admdate': '2000-04-06',
#   'admid': '0010446016',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 6, 0, 0)},
#  {'admdate': '2000-04-07',
#   'admid': '0010447533',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 7, 0, 0)},
#  {'admdate': '2000-04-10',
#   'admid': '0010448055',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 10, 0, 0)},
#  {'admdate': '2000-04-11',
#   'admid': '0010447612',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 11, 0, 0)},
#  {'admdate': '2000-04-12',
#   'admid': '0010446068',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 12, 0, 0)},
#  {'admdate': '2000-04-13',
#   'admid': '0010445054',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 13, 0, 0)},
#  {'admdate': '2000-04-14',
#   'admid': '0010447549',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'admdate': '2000-04-14',
#   'admid': '0010448048',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'admdate': '2000-04-14',
#   'admid': '0010448049',
#   'codes': '401',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025991526',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041098876',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048530506',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056552169',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064440037',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072666918',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085658864',
#   'admdate': '2000-04-14',
#   'admit_date': datetime.datetime(2000, 4, 14, 0, 0)},
#  {'admdate': '2000-04-17',
#   'admid': '0010447576',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 17, 0, 0)},
#  {'admdate': '2000-04-18',
#   'admid': '0010448057',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 18, 0, 0)},
#  {'admdate': '2000-04-19',
#   'admid': '0010445984',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 4, 19, 0, 0)},
#  {'admdate': '2000-05-01',
#   'admid': '0010447904',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 1, 0, 0)},
#  {'admdate': '2000-05-03',
#   'admid': '0010448536',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 3, 0, 0)},
#  {'admdate': '2000-05-05',
#   'admid': '0010446064',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 5, 0, 0)},
#  {'admdate': '2000-05-08',
#   'admid': '0010448053',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 8, 0, 0)},
#  {'admdate': '2000-05-10',
#   'admid': '0010447901',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 10, 0, 0)},
#  {'admdate': '2000-05-11',
#   'admid': '0010448056',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 11, 0, 0)},
#  {'admdate': '2000-05-12',
#   'admid': '0010448010',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 12, 0, 0)},
#  {'admdate': '2000-05-15',
#   'admid': '0010446077',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 15, 0, 0)},
#  {'admdate': '2000-05-16',
#   'admid': '0010448534',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 16, 0, 0)},
#  {'admdate': '2000-05-17',
#   'admid': '0010446046',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 17, 0, 0)},
#  {'admdate': '2000-05-18',
#   'admid': '0010447518',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 18, 0, 0)},
#  {'admdate': '2000-05-22',
#   'admid': '0010448616',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 22, 0, 0)},
#  {'admdate': '2000-05-23',
#   'admid': '0010448117',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 23, 0, 0)},
#  {'admdate': '2000-05-24',
#   'admid': '0010448044',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 24, 0, 0)},
#  {'admdate': '2000-05-30',
#   'admid': '0010445924',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 30, 0, 0)},
#  {'admdate': '2000-05-31',
#   'admid': '0010447948',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 5, 31, 0, 0)},
#  {'admdate': '2000-06-01',
#   'admid': '0010447544',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 1, 0, 0)},
#  {'admdate': '2000-06-02',
#   'admid': '0010448045',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 2, 0, 0)},
#  {'admdate': '2000-06-05',
#   'admid': '0010448606',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 5, 0, 0)},
#  {'admdate': '2000-06-06',
#   'admid': '0010447994',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 6, 0, 0)},
#  {'admdate': '2000-06-08',
#   'admid': '0010448012',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 8, 0, 0)},
#  {'admdate': '2000-06-09',
#   'admid': '0010448060',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 9, 0, 0)},
#  {'admdate': '2000-06-12',
#   'admid': '0010447880',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 12, 0, 0)},
#  {'admdate': '2000-06-13',
#   'admid': '0010448021',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 13, 0, 0)},
#  {'admdate': '2000-06-16',
#   'admid': '0010448014',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 16, 0, 0)},
#  {'admdate': '2000-06-19',
#   'admid': '0010447615',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 19, 0, 0)},
#  {'admdate': '2000-06-20',
#   'admid': '0010446074',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 20, 0, 0)},
#  {'admdate': '2000-06-21',
#   'admid': '0010447594',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 21, 0, 0)},
#  {'admdate': '2000-06-22',
#   'admid': '0010447640',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 22, 0, 0)},
#  {'admdate': '2000-06-23',
#   'admid': '0010447985',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 23, 0, 0)},
#  {'admdate': '2000-06-26',
#   'admid': '0010447561',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 26, 0, 0)},
#  {'admdate': '2000-06-27',
#   'admid': '0010445066',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 27, 0, 0)},
#  {'admdate': '2000-06-28',
#   'admid': '0010446017',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 28, 0, 0)},
#  {'admdate': '2000-06-30',
#   'admid': '0010447634',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 6, 30, 0, 0)},
#  {'admdate': '2000-07-01',
#   'admid': '0010445982',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 1, 0, 0)},
#  {'admdate': '2000-07-03',
#   'admid': '0010448074',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 3, 0, 0)},
#  {'admdate': '2000-07-06',
#   'admid': '0010447895',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 6, 0, 0)},
#  {'admdate': '2000-07-07',
#   'admid': '0010447891',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 7, 0, 0)},
#  {'admdate': '2000-07-11',
#   'admid': '0010447599',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 11, 0, 0)},
#  {'admdate': '2000-07-12',
#   'admid': '0010449494',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 12, 0, 0)},
#  {'admdate': '2000-07-13',
#   'admid': '0010447918',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 13, 0, 0)},
#  {'admdate': '2000-07-14',
#   'admid': '0010449490',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 14, 0, 0)},
#  {'admdate': '2000-07-18',
#   'admid': '0010448565',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 18, 0, 0)},
#  {'admdate': '2000-07-19',
#   'admid': '0010447588',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 19, 0, 0)},
#  {'admdate': '2000-07-20',
#   'admid': '0010447611',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 20, 0, 0)},
#  {'admdate': '2000-07-21',
#   'admid': '0010448105',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 21, 0, 0)},
#  {'admdate': '2000-07-24',
#   'admid': '0010447937',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 24, 0, 0)},
#  {'admdate': '2000-07-26',
#   'admid': '0010447940',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 26, 0, 0)},
#  {'admdate': '2000-07-27',
#   'admid': '0010445981',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 27, 0, 0)},
#  {'admdate': '2000-07-28',
#   'admid': '0010446054',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 28, 0, 0)},
#  {'admdate': '2000-07-31',
#   'admid': '0010449497',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 7, 31, 0, 0)},
#  {'admdate': '2000-08-03',
#   'admid': '0010446034',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 3, 0, 0)},
#  {'admdate': '2000-08-07',
#   'admid': '0010446056',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 7, 0, 0)},
#  {'admdate': '2000-08-08',
#   'admid': '0010448051',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 8, 0, 0)},
#  {'admdate': '2000-08-09',
#   'admid': '0010445065',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 9, 0, 0)},
#  {'admdate': '2000-08-10',
#   'admid': '0010447927',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 10, 0, 0)},
#  {'admdate': '2000-08-11',
#   'admid': '0010445997',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 11, 0, 0)},
#  {'admdate': '2000-08-14',
#   'admid': '0010447959',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 14, 0, 0)},
#  {'admdate': '2000-08-15',
#   'admid': '0010446071',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 15, 0, 0)},
#  {'admdate': '2000-08-16',
#   'admid': '0010447638',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 16, 0, 0)},
#  {'admdate': '2000-08-17',
#   'admid': '0010448591',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 17, 0, 0)},
#  {'admdate': '2000-08-18',
#   'admid': '0010448091',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 18, 0, 0)},
#  {'admdate': '2000-08-18',
#   'admid': '0010449480',
#   'codes': '274.1',
#   'admit_date': datetime.datetime(2000, 8, 18, 0, 0)},
#  {'admdate': '2000-08-18',
#   'admid': '0010449481',
#   'codes': '274',
#   'admit_date': datetime.datetime(2000, 8, 18, 0, 0)},
#  {'admdate': '2000-08-21',
#   'admid': '0010446055',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 21, 0, 0)},
#  {'admdate': '2000-08-22',
#   'admid': '0010446037',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 22, 0, 0)},
#  {'admdate': '2000-08-23',
#   'admid': '0010447643',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 23, 0, 0)},
#  {'admdate': '2000-08-24',
#   'admid': '0010446021',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 24, 0, 0)},
#  {'admdate': '2000-08-25',
#   'admid': '0010448094',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 25, 0, 0)},
#  {'admdate': '2000-08-30',
#   'admid': '0010447923',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 8, 30, 0, 0)},
#  {'admdate': '2000-09-01',
#   'admid': '0010448067',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 1, 0, 0)},
#  {'admdate': '2000-09-05',
#   'admid': '0010447562',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 5, 0, 0)},
#  {'admdate': '2000-09-06',
#   'admid': '0010448535',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 6, 0, 0)},
#  {'admdate': '2000-09-07',
#   'admid': '0010447526',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 7, 0, 0)},
#  {'admdate': '2000-09-11',
#   'admid': '0010446033',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 11, 0, 0)},
#  {'admdate': '2000-09-12',
#   'admid': '0010448617',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 12, 0, 0)},
#  {'admdate': '2000-09-13',
#   'admid': '0010449422',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 13, 0, 0)},
#  {'admdate': '2000-09-14',
#   'admid': '0010448521',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 14, 0, 0)},
#  {'admdate': '2000-09-15',
#   'admid': '0010447540',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 15, 0, 0)},
#  {'admdate': '2000-09-18',
#   'admid': '0010447596',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 18, 0, 0)},
#  {'admdate': '2000-09-19',
#   'admid': '0010446078',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 19, 0, 0)},
#  {'admdate': '2000-09-20',
#   'admid': '0010446006',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 20, 0, 0)},
#  {'admdate': '2000-09-21',
#   'admid': '0010445973',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 21, 0, 0)},
#  {'admdate': '2000-09-25',
#   'admid': '0010447564',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 25, 0, 0)},
#  {'admdate': '2000-09-26',
#   'admid': '0010447642',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 26, 0, 0)},
#  {'admdate': '2000-09-27',
#   'admid': '0010446001',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 27, 0, 0)},
#  {'admdate': '2000-09-28',
#   'admid': '0010447543',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 9, 28, 0, 0)},
#  {'admit_date': datetime.datetime(2000, 9, 30, 0, 0),
#   'codes': '_',
#   'hospital': 'n/a',
#   'admid': '0010446036_1'},
#  {'admdate': '2000-10-02',
#   'admid': '0010448039',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 2, 0, 0)},
#  {'admdate': '2000-10-03',
#   'admid': '0010445983',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 3, 0, 0)},
#  {'admdate': '2000-10-04',
#   'admid': '0010481552',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 4, 0, 0)},
#  {'admdate': '2000-10-05',
#   'admid': '0010448613',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 5, 0, 0)},
#  {'admdate': '2000-10-06',
#   'admid': '0010447558',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 6, 0, 0)},
#  {'admdate': '2000-10-10',
#   'admid': '0010447513',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 10, 0, 0)},
#  {'admdate': '2000-10-11',
#   'admid': '0010448040',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 11, 0, 0)},
#  {'admdate': '2000-10-12',
#   'admid': '0010446075',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 12, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445949',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445950',
#   'codes': '272',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445951',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445952',
#   'codes': '401',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445953',
#   'codes': '740.3',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445954',
#   'codes': '740',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445955',
#   'codes': '274.1',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-13',
#   'admid': '0010445956',
#   'codes': '274',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Albumin2',
#   'admid': '2000472517',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'AlkalinePhosphatase3',
#   'admid': '2005764734',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'ALT1',
#   'admid': '2010713163',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'AST1',
#   'admid': '2015968725',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Bilirubin2',
#   'admid': '2020953282',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'BUN3',
#   'admid': '2025990564',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041097849',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048557939',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056551846',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064485946',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Potassium03',
#   'admid': '2072668080',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Protein2',
#   'admid': '2080717385',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085654687',
#   'admdate': '2000-10-13',
#   'admit_date': datetime.datetime(2000, 10, 13, 0, 0)},
#  {'admdate': '2000-10-17',
#   'admid': '0010448030',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 17, 0, 0)},
#  {'admdate': '2000-10-18',
#   'admid': '0010447971',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 18, 0, 0)},
#  {'admdate': '2000-10-19',
#   'admid': '0010447896',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 19, 0, 0)},
#  {'admdate': '2000-10-20',
#   'admid': '0010448597',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 20, 0, 0)},
#  {'admdate': '2000-10-23',
#   'admid': '0010447607',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 23, 0, 0)},
#  {'admdate': '2000-10-24',
#   'admid': '0010447936',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 24, 0, 0)},
#  {'admdate': '2000-10-25',
#   'admid': '0010447899',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 25, 0, 0)},
#  {'admdate': '2000-10-25',
#   'admid': '0010448069',
#   'codes': '274.1',
#   'admit_date': datetime.datetime(2000, 10, 25, 0, 0)},
#  {'admdate': '2000-10-25',
#   'admid': '0010448070',
#   'codes': '274',
#   'admit_date': datetime.datetime(2000, 10, 25, 0, 0)},
#  {'admdate': '2000-10-26',
#   'admid': '0010447580',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 26, 0, 0)},
#  {'admdate': '2000-10-30',
#   'admid': '0010449421',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 30, 0, 0)},
#  {'admdate': '2000-10-31',
#   'admid': '0010445976',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 10, 31, 0, 0)},
#  {'admdate': '2000-11-01',
#   'admid': '0010445974',
#   'codes': '274.1',
#   'admit_date': datetime.datetime(2000, 11, 1, 0, 0)},
#  {'admdate': '2000-11-01',
#   'admid': '0010445975',
#   'codes': '274',
#   'admit_date': datetime.datetime(2000, 11, 1, 0, 0)},
#  {'admdate': '2000-11-01',
#   'admid': '0010449441',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 1, 0, 0)},
#  {'admdate': '2000-11-03',
#   'admid': '0010448599',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 3, 0, 0)},
#  {'admdate': '2000-11-06',
#   'admid': '0010447609',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 6, 0, 0)},
#  {'admdate': '2000-11-07',
#   'admid': '0010447644',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 7, 0, 0)},
#  {'admdate': '2000-11-08',
#   'admid': '0010445985',
#   'codes': '716.9',
#   'admit_date': datetime.datetime(2000, 11, 8, 0, 0)},
#  {'admdate': '2000-11-08',
#   'admid': '0010445986',
#   'codes': '716',
#   'admit_date': datetime.datetime(2000, 11, 8, 0, 0)},
#  {'admdate': '2000-11-08',
#   'admid': '0010449424',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 8, 0, 0)},
#  {'admdate': '2000-11-09',
#   'admid': '0010447616',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 9, 0, 0)},
#  {'admdate': '2000-11-09',
#   'admid': '0010448042',
#   'codes': '716.9',
#   'admit_date': datetime.datetime(2000, 11, 9, 0, 0)},
#  {'admdate': '2000-11-09',
#   'admid': '0010448043',
#   'codes': '716',
#   'admit_date': datetime.datetime(2000, 11, 9, 0, 0)},
#  {'admdate': '2000-11-13',
#   'admid': '0010448525',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 13, 0, 0)},
#  {'admdate': '2000-11-14',
#   'admid': '0010448552',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 14, 0, 0)},
#  {'admdate': '2000-11-15',
#   'admid': '0010448101',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 15, 0, 0)},
#  {'admdate': '2000-11-16',
#   'admid': '0010447559',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 16, 0, 0)},
#  {'admdate': '2000-11-17',
#   'admid': '0010448089',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 17, 0, 0)},
#  {'admdate': '2000-11-20',
#   'admid': '0010447536',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 20, 0, 0)},
#  {'admdate': '2000-11-21',
#   'admid': '0010446027',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 21, 0, 0)},
#  {'admdate': '2000-11-22',
#   'admid': '0010449459',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 22, 0, 0)},
#  {'admdate': '2000-11-27',
#   'admid': '0010448118',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 27, 0, 0)},
#  {'admdate': '2000-11-28',
#   'admid': '0010445957',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 28, 0, 0)},
#  {'admdate': '2000-11-29',
#   'admid': '0010447530',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 29, 0, 0)},
#  {'admdate': '2000-11-30',
#   'admid': '0010447541',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 11, 30, 0, 0)},
#  {'admdate': '2000-12-01',
#   'admid': '0010448614',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 1, 0, 0)},
#  {'admdate': '2000-12-05',
#   'admid': '0010447908',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 5, 0, 0)},
#  {'admdate': '2000-12-06',
#   'admid': '0010448590',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 6, 0, 0)},
#  {'admdate': '2000-12-07',
#   'admid': '0010448076',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 7, 0, 0)},
#  {'admdate': '2000-12-08',
#   'admid': '0010449434',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 8, 0, 0)},
#  {'admdate': '2000-12-12',
#   'admid': '0010449447',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 12, 0, 0)},
#  {'admdate': '2000-12-15',
#   'admid': '0010449501',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 15, 0, 0)},
#  {'admdate': '2000-12-18',
#   'admid': '0010447881',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 18, 0, 0)},
#  {'admdate': '2000-12-19',
#   'admid': '0010445070',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 19, 0, 0)},
#  {'admdate': '2000-12-20',
#   'admid': '0010447600',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 20, 0, 0)},
#  {'admdate': '2000-12-27',
#   'admid': '0010447509',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 27, 0, 0)},
#  {'admdate': '2000-12-28',
#   'admid': '0010445929',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 28, 0, 0)},
#  {'admdate': '2000-12-29',
#   'admid': '0010447525',
#   'codes': '317',
#   'admit_date': datetime.datetime(2000, 12, 29, 0, 0)},
#  {'admdate': '2001-01-03',
#   'admid': '0010447919',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 3, 0, 0)},
#  {'admdate': '2001-01-04',
#   'admid': '0010447645',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 4, 0, 0)},
#  {'admdate': '2001-01-05',
#   'admid': '0010445977',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 5, 0, 0)},
#  {'admdate': '2001-01-09',
#   'admid': '0010447911',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 9, 0, 0)},
#  {'admdate': '2001-01-10',
#   'admid': '0010447571',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 10, 0, 0)},
#  {'admdate': '2001-01-11',
#   'admid': '0010447939',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 11, 0, 0)},
#  {'admdate': '2001-01-12',
#   'admid': '0010448033',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 12, 0, 0)},
#  {'admdate': '2001-01-16',
#   'admid': '0010448025',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 16, 0, 0)},
#  {'admdate': '2001-01-17',
#   'admid': '0010448095',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 17, 0, 0)},
#  {'admdate': '2001-01-18',
#   'admid': '0010447949',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 18, 0, 0)},
#  {'admdate': '2001-01-19',
#   'admid': '0010447565',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 19, 0, 0)},
#  {'admdate': '2001-01-22',
#   'admid': '0010448046',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 22, 0, 0)},
#  {'admdate': '2001-01-23',
#   'admid': '0010448537',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 23, 0, 0)},
#  {'admdate': '2001-01-24',
#   'admid': '0010449493',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 24, 0, 0)},
#  {'admdate': '2001-01-25',
#   'admid': '0010448560',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 25, 0, 0)},
#  {'admdate': '2001-01-29',
#   'admid': '0010447884',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 29, 0, 0)},
#  {'admdate': '2001-01-30',
#   'admid': '0010448538',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 1, 30, 0, 0)},
#  {'admdate': '2001-02-05',
#   'admid': '0010447585',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 5, 0, 0)},
#  {'admdate': '2001-02-06',
#   'admid': '0010449463',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 6, 0, 0)},
#  {'admdate': '2001-02-07',
#   'admid': '0010448558',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 7, 0, 0)},
#  {'admdate': '2001-02-08',
#   'admid': '0010449485',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 8, 0, 0)},
#  {'admdate': '2001-02-09',
#   'admid': '0010447970',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 9, 0, 0)},
#  {'admdate': '2001-02-11',
#   'admid': '0010449427',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 11, 0, 0)},
#  {'admdate': '2001-02-12',
#   'admid': '0010447870',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 12, 0, 0)},
#  {'admdate': '2001-02-13',
#   'admid': '0010445934',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 13, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447960',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447961',
#   'codes': '272',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447962',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447963',
#   'codes': '317',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447964',
#   'codes': '760',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447965',
#   'codes': '716.9',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447966',
#   'codes': '716',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'admdate': '2001-02-15',
#   'admid': '0010447967',
#   'codes': '465',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025991339',
#   'admdate': '2001-02-15',
#   'admit_date': datetime.datetime(2001, 2, 15, 0, 0)},
# ...
#   'admid': '2056549915',
#   'admdate': '2002-10-18',
#   'admit_date': datetime.datetime(2002, 10, 18, 0, 0)},
#  {'codes': 'Glucose21',
#   'admid': '2064485568',
#   'admdate': '2002-10-18',
#   'admit_date': datetime.datetime(2002, 10, 18, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072666914',
#   'admdate': '2002-10-18',
#   'admit_date': datetime.datetime(2002, 10, 18, 0, 0)},
#  {'codes': 'Protein2',
#   'admid': '2080719061',
#   'admdate': '2002-10-18',
#   'admit_date': datetime.datetime(2002, 10, 18, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085659021',
#   'admdate': '2002-10-18',
#   'admit_date': datetime.datetime(2002, 10, 18, 0, 0)},
#  {'admdate': '2002-10-19',
#   'admid': '0010445991',
#   'codes': '370.1',
#   'admit_date': datetime.datetime(2002, 10, 19, 0, 0)},
#  {'admdate': '2002-10-19',
#   'admid': '0010445992',
#   'codes': '370',
#   'admit_date': datetime.datetime(2002, 10, 19, 0, 0)},
#  {'admdate': '2002-10-23',
#   'admid': '0010447931',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 10, 23, 0, 0)},
#  {'admdate': '2002-10-23',
#   'admid': '0010448595',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2002, 10, 23, 0, 0)},
#  {'admdate': '2002-10-23',
#   'admid': '0010448596',
#   'codes': '369',
#   'admit_date': datetime.datetime(2002, 10, 23, 0, 0)},
#  {'admdate': '2002-11-08',
#   'admid': '0010445966',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 11, 8, 0, 0)},
#  {'admdate': '2002-11-13',
#   'admid': '0010447597',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2002, 11, 13, 0, 0)},
#  {'admdate': '2002-11-13',
#   'admid': '0010447598',
#   'codes': '369',
#   'admit_date': datetime.datetime(2002, 11, 13, 0, 0)},
#  {'admdate': '2002-11-20',
#   'admid': '0010449502',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 11, 20, 0, 0)},
#  {'admdate': '2002-11-25',
#   'admid': '0010447563',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 11, 25, 0, 0)},
#  {'admdate': '2002-11-25',
#   'admid': '0010447613',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(2002, 11, 25, 0, 0)},
#  {'admdate': '2002-12-04',
#   'admid': '0010449428',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 4, 0, 0)},
#  {'admdate': '2002-12-09',
#   'admid': '0010449495',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 9, 0, 0)},
#  {'admdate': '2002-12-10',
#   'admid': '0010446072',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 10, 0, 0)},
#  {'admdate': '2002-12-11',
#   'admid': '0010447902',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2002, 12, 11, 0, 0)},
#  {'admdate': '2002-12-11',
#   'admid': '0010447903',
#   'codes': '369',
#   'admit_date': datetime.datetime(2002, 12, 11, 0, 0)},
#  {'admdate': '2002-12-17',
#   'admid': '0010448026',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 17, 0, 0)},
#  {'admdate': '2002-12-18',
#   'admid': '0010447926',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 18, 0, 0)},
#  {'admdate': '2002-12-20',
#   'admid': '0010448100',
#   'codes': '317',
#   'admit_date': datetime.datetime(2002, 12, 20, 0, 0)},
#  {'admdate': '2003-01-08',
#   'admid': '0021779152',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 1, 8, 0, 0)},
#  {'admdate': '2003-01-08',
#   'admid': '0021779153',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 1, 8, 0, 0)},
#  {'admdate': '2003-01-08',
#   'admid': '0021779163',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 1, 8, 0, 0)},
#  {'admdate': '2003-01-22',
#   'admid': '0021778552',
#   'codes': '323',
#   'admit_date': datetime.datetime(2003, 1, 22, 0, 0)},
#  {'admdate': '2003-01-23',
#   'admid': '0021778512',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 1, 23, 0, 0)},
#  {'admdate': '2003-01-31',
#   'admid': '0021778458',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 1, 31, 0, 0)},
#  {'admdate': '2003-01-31',
#   'admid': '0021779148',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 1, 31, 0, 0)},
#  {'admdate': '2003-01-31',
#   'admid': '0021779149',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 1, 31, 0, 0)},
#  {'admdate': '2003-02-06',
#   'admid': '0021778529',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 2, 6, 0, 0)},
#  {'admdate': '2003-02-06',
#   'admid': '0021778530',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 2, 6, 0, 0)},
#  {'admdate': '2003-02-10',
#   'admid': '0021778560',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 2, 10, 0, 0)},
#  {'admdate': '2003-02-12',
#   'admid': '0021778482',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 2, 12, 0, 0)},
#  {'admdate': '2003-02-12',
#   'admid': '0021778538',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 2, 12, 0, 0)},
#  {'admdate': '2003-02-12',
#   'admid': '0021778539',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 2, 12, 0, 0)},
#  {'admdate': '2003-02-13',
#   'admid': '0021778511',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 2, 13, 0, 0)},
#  {'admdate': '2003-02-26',
#   'admid': '0021778514',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 2, 26, 0, 0)},
#  {'admdate': '2003-02-26',
#   'admid': '0021778515',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 2, 26, 0, 0)},
#  {'admdate': '2003-02-26',
#   'admid': '0021778551',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 2, 26, 0, 0)},
#  {'admdate': '2003-03-10',
#   'admid': '0021778562',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(2003, 3, 10, 0, 0)},
#  {'admdate': '2003-03-10',
#   'admid': '0021778563',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 3, 10, 0, 0)},
#  {'admdate': '2003-03-12',
#   'admid': '0021778499',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 3, 12, 0, 0)},
#  {'admdate': '2003-03-19',
#   'admid': '0021778456',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 3, 19, 0, 0)},
#  {'admdate': '2003-03-20',
#   'admid': '0021779187',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 3, 20, 0, 0)},
#  {'admdate': '2003-03-26',
#   'admid': '0021778486',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 3, 26, 0, 0)},
#  {'admdate': '2003-04-09',
#   'admid': '0021778481',
#   'codes': '370',
#   'admit_date': datetime.datetime(2003, 4, 9, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778569',
#   'codes': '530.11',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778570',
#   'codes': '530.1',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778571',
#   'codes': '530',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778572',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778573',
#   'codes': '272',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778574',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778575',
#   'codes': '401',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778576',
#   'codes': '274.1',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-21',
#   'admid': '0021778577',
#   'codes': '274',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Albumin2',
#   'admid': '2000472515',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'AlkalinePhosphatase3',
#   'admid': '2005779026',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'ALT2',
#   'admid': '2010714390',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'AST2',
#   'admid': '2015955583',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Bilirubin2',
#   'admid': '2021043864',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025991623',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Calcium3',
#   'admid': '2033685247',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041098521',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048558821',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056549376',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064439164',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072667024',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Protein2',
#   'admid': '2080717798',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Sodium2',
#   'admid': '2085656935',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Wmed',
#   'admid': '0003811025',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Hlow',
#   'admid': '0039763220',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'codes': 'Phigh',
#   'admid': '0068802043',
#   'admdate': '2003-04-21',
#   'admit_date': datetime.datetime(2003, 4, 21, 0, 0)},
#  {'admdate': '2003-04-23',
#   'admid': '0021778459',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 4, 23, 0, 0)},
#  {'admdate': '2003-05-07',
#   'admid': '0021778549',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 5, 7, 0, 0)},
#  {'admdate': '2003-05-21',
#   'admid': '0021778579',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 5, 21, 0, 0)},
#  {'admdate': '2003-05-21',
#   'admid': '0021778580',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 5, 21, 0, 0)},
#  {'admdate': '2003-05-21',
#   'admid': '0021779183',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 5, 21, 0, 0)},
#  {'admdate': '2003-06-04',
#   'admid': '0021778559',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 6, 4, 0, 0)},
#  {'admdate': '2003-06-19',
#   'admid': '0021778544',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 6, 19, 0, 0)},
#  {'admdate': '2003-06-20',
#   'admid': '0021778485',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 6, 20, 0, 0)},
#  {'admdate': '2003-07-02',
#   'admid': '0021778471',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 7, 2, 0, 0)},
#  {'admdate': '2003-07-16',
#   'admid': '0021778540',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(2003, 7, 16, 0, 0)},
#  {'admdate': '2003-07-16',
#   'admid': '0021778541',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 7, 16, 0, 0)},
#  {'admdate': '2003-07-21',
#   'admid': '0021779172',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 7, 21, 0, 0)},
#  {'admdate': '2003-07-23',
#   'admid': '0021779167',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 7, 23, 0, 0)},
#  {'admdate': '2003-07-30',
#   'admid': '0021778503',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 7, 30, 0, 0)},
#  {'admdate': '2003-08-06',
#   'admid': '0021778500',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 8, 6, 0, 0)},
#  {'admdate': '2003-08-07',
#   'admid': '0021778542',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 8, 7, 0, 0)},
#  {'admdate': '2003-08-07',
#   'admid': '0021778543',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 8, 7, 0, 0)},
#  {'admdate': '2003-08-20',
#   'admid': '0021778545',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 8, 20, 0, 0)},
#  {'admdate': '2003-09-03',
#   'admid': '0021778513',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 9, 3, 0, 0)},
#  {'admdate': '2003-09-08',
#   'admid': '0021779185',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 9, 8, 0, 0)},
#  {'admdate': '2003-09-17',
#   'admid': '0021778483',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 9, 17, 0, 0)},
#  {'admdate': '2003-09-18',
#   'admid': '0021778460',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 9, 18, 0, 0)},
#  {'admdate': '2003-09-19',
#   'admid': '0021778535',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 9, 19, 0, 0)},
#  {'admit_date': datetime.datetime(2003, 9, 30, 0, 0),
#   'codes': '_',
#   'hospital': 'n/a',
#   'admid': '0010446036_4'},
#  {'admdate': '2003-10-08',
#   'admid': '0021778501',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 10, 8, 0, 0)},
#  {'admdate': '2003-10-16',
#   'admid': '0021779188',
#   'codes': '369.2',
#   'admit_date': datetime.datetime(2003, 10, 16, 0, 0)},
#  {'admdate': '2003-10-16',
#   'admid': '0021779189',
#   'codes': '369',
#   'admit_date': datetime.datetime(2003, 10, 16, 0, 0)},
#  {'admdate': '2003-10-20',
#   'admid': '0021778527',
#   'codes': '317.1',
#   'admit_date': datetime.datetime(2003, 10, 20, 0, 0)},
#  {'admdate': '2003-10-20',
#   'admid': '0021778528',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 10, 20, 0, 0)},
#  {'admdate': '2003-10-27',
#   'admid': '0021778520',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 10, 27, 0, 0)},
#  {'admdate': '2003-10-29',
#   'admid': '0021778505',
#   'codes': '317',
#   'admit_date': datetime.datetime(2003, 10, 29, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778464',
#   'codes': '720',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778465',
#   'codes': '272.1',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778466',
#   'codes': '272',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778467',
#   'codes': '401.1',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778468',
#   'codes': '401',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778469',
#   'codes': '716.9',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'admdate': '2003-11-03',
#   'admid': '0021778470',
#   'codes': '716',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Albumin2',
#   'admid': '2000435627',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'AlkalinePhosphatase3',
#   'admid': '2005782270',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'ALT2',
#   'admid': '2010725972',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'AST3',
#   'admid': '2016024026',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Bilirubin2',
#   'admid': '2020933447',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'BUN1',
#   'admid': '2025992396',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Calcium3',
#   'admid': '2033684350',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'CarbonDioxide2',
#   'admid': '2041098299',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Chloride1',
#   'admid': '2048558145',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Creatinine2',
#   'admid': '2056549625',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Glucose23',
#   'admid': '2064441708',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Potassium02',
#   'admid': '2072674578',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  {'codes': 'Protein2',
#   'admid': '2080719991',
#   'admdate': '2003-11-03',
#   'admit_date': datetime.datetime(2003, 11, 3, 0, 0)},
#  ...]

# %%
if outcome == True and lookback > outcome_date:
    lookback = outcome_date

# %%
lookback
# Out:
# datetime.datetime(2015, 4, 10, 0, 0)

# %%
enumerate(events)

# %%
for i in events:
    date = events['admdate]

# %%
avai_indices, gold = get_avai_trajectory_indices1 (patient_dict, events, feat_subgroup, split_group)

# %%
patient_dict.update({'avai_indices': avai_indices, 'y': gold})
patient_dict.update({'events': events})

# %%
patient_id

# %%
O = []

# %%
obs_time_end

# %%
index_date

# %%
outcome_date

# %%
patient = patient_dict

# %%
len( patient['events'])

# %%
num_time_steps, max_time = len([1,3,6,12]), max([1,3,6,12])

# %%
y = days_to_censor < (max_time * 30) and patient['outcome']

# %%
        y_seq = np.zeros(num_time_steps)

# %%
days_to_censor

# %%
index_date

# %%
 def get_label2 (patient, index_date):
       # event = patient['events'][idx]
        days_to_censor = (patient['outcome_date'] - index_date).days
         
        num_time_steps, max_time = len([1,3,6,12]), max([1,3,6,12])
        y = patient['outcome'] #days_to_censor < (max_time * 30) and  
        y_seq = np.zeros(num_time_steps)
        time_at_event = min([i for i, mo in enumerate([1,3,6,12])
                             if days_to_censor < (mo * 30)]) if days_to_censor < (max_time * 30) else num_time_steps - 1
        if y:
            y_seq[time_at_event:] = 1
        y_mask = np.array([1] * (time_at_event + 1) + [0] * (num_time_steps - (time_at_event + 1)))
        
        assert time_at_event >= 0 and len(y_seq) == len(y_mask)
        return y, y_seq.astype('float64'), y_mask.astype('float64'), time_at_event, days_to_censor

# %%
days_to_censor

# %%
 (max_time * 30)

# %%
days_to_censor = (patient['outcome_date'] - index_date).days
num_time_steps, max_time = len([1,3,6,12]), max([1,3,6,12])
y = patient['outcome']
y_seq = np.zeros(num_time_steps)
time_at_event = min([i for i, mo in enumerate([1,3,6,12])
                     if days_to_censor < (mo * 30)]) if days_to_censor < (max_time * 30) else num_time_steps

# %%
time_at_event

# %%
if y:
    y_seq[time_at_event:] = 1
y_mask = np.array([1] * (time_at_event ) + [0] * (num_time_steps - (time_at_event )))

# %%
y

# %%
y_mask

# %%
y_seq

# %%
num_time_steps, max_time = len([1,3,6,12]), max([1,3,6,12])

# %%
y_mask

# %%
 np.array([1] * (time_at_event + 1) + [0] * (num_time_steps - (time_at_event + 1)))

# %%
max_time

# %%
days_to_censor

# %%
max_time*30

# %%
time_at_event

# %%
    def time_label(self, patient, mo1,mo3,mo6):
        '''
            outcome_date: outcome occurance or END_OF_TIME_DATE
            time_at_event: years to outcome_data/END_OF_TIME_DATE
            y_seq: zero array unless ever_develops_outcome => y_seq[time_at_event:]=1
                    * Used as golds in cumulative_probability_layer
            y_mask: how many years left in the disease window,
                    ([1] for 0:time_at_event years and [0] for the rest)
                    (without linear interpolation, y_mask looks like complement of y_seq)
                    * Used for mask loss in cumulative_probability_layer
            Ex1:  a patient has the outcome in 3 years
                    time_at_event: 2,
                    y_seq: [0, 0, 1, 1, 1]
                    y_mask: [1, 1, 1, 0, 0]
            Ex2:  a patient never gets outcome
                    y_seq: [0, 0, 0, 0, 0]
                    y_mask: [1, 1, 0, 0, 0]
                    time_at_event: 1,
        '''
        event1 = patient['events'][mo1]
        event3 = patient['events'][mo3]
        event6 = patient['events'][mo6]
        
        
        days_to_censor1 = (patient['outcome_date'] - event1 ['admit_date']).days
        days_to_censor2 = (patient['outcome_date'] - event3 ['admit_date']).days
        days_to_censor3 = (patient['outcome_date'] - event6 ['admit_date']).days
         
        num_time_steps, max_time = len(self.args.month_endpoints), max(self.args.month_endpoints)
        y = days_to_censor < (max_time * 30) and patient['outcome']
        y_seq = np.zeros(num_time_steps)
        time_at_event = min([i for i, mo in enumerate(self.args.month_endpoints)
                             if days_to_censor < (mo * 30)]) if days_to_censor < (max_time * 30) else num_time_steps - 1
        if y:
            y_seq[time_at_event:] = 1
        y_mask = np.array([1] * (time_at_event + 1) + [0] * (num_time_steps - (time_at_event + 1)))
        
        assert time_at_event >= 0 and len(y_seq) == len(y_mask)
        return y, y_seq.astype('float64'), y_mask.astype('float64'), time_at_event, days_to_censor

# %%
patient_id

# %%
patient_metadata.keys()

# %%
patient_id

# %%
patient_dict = {'patient_id': patient_id}

# %%
patient_dict.update({'events': events})

# %%
feat_subgroup = {'birth_date': patient_metadata[patient_id]['birthdate']}

# %%
feat_subgroup

# %%
 patient_dict.update({'outcome': outcome,
                                 'dob': dob,
                                 'outcome_date': outcome_date,
                                 'split_group': patient_metadata[patient_id]['split_group'],
                                 'obs_time_end': obs_time_end,
                                 'index_date': index_date,
                                 'dx_date': dx_date,
                                 'ks': ks,
                                 'sex': sex,
                                 'bmi': bmi,
                                 'race': race})

# %%
patient_metadata[patient_id]['split_group']

# %%
split_group = 'dev'

# %%
avai_indices, gold = get_avai_trajectory_indices(patient_dict, events, feat_subgroup, split_group, args)

# %%
patient_dict.update({'avai_indices': avai_indices, 'y': gold})

# %%
patients = np.array([])

# %%
patients = np.append(patients, patient_dict)

# %%
patient = patients[0]

# %%
selected_idx = [random.choice(patient['avai_indices']) for _ in range (4)]

# %%
patient['avai_indices']

# %%
selected_idx

# %%
idx = selected_idx[0]

# %%
events_to_date = patient['events'][: selected_idx[2] + 1]

# %%
len(events_to_date)

# %%
ev_samp =  patient['events'] [0:20]

# %%
ev_samp [: 3 +1]

# %%
ev_samp[: 17 + 1]

# %%
ev_samp[: 13 + 1]

# %%
patient['events'][2150:2200]

# %%
events_to_date[1:10]

# %%
outcome

# %%
def get_time_seq1( events, reference_date):
    deltas = np.array([abs((reference_date - event['admit_date']).days) for event in events])
    multipliers = 2 * np.pi / (np.linspace(start=MIN_TIME_EMBED_PERIOD_IN_DAYS, stop=MAX_TIME_EMBED_PERIOD_IN_DAYS,
                                           num=self.args.time_embed_dim))

    deltas, multipliers = deltas.reshape(len(deltas), 1), multipliers.reshape(1, len(multipliers))
    positional_embeddings = np.cos(deltas * multipliers)
    return max(deltas), positional_embeddings
